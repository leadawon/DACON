# %%
# 모든 항목을 국가로 매핑하는 개선된 딕셔너리
country_mapping1 = {
  "MRCHROME": "other",
  "BlackBerry": "other",
  "Playstation Vita Browser": "other",
  "Maxthon": "other",
  "Nokia Browser": "other",
  "Nintendo Browser": "other",
  "Mozilla": "other",
  "+Simple Browser": "other",
  "SeaMonkey": "other",
  "DESKTOP": "other",
  "Iron": "other",
  "Browser": "other",
  "Konqueror": "other",
  "YE": "other",
  "osee2unifiedRelease": "other",
  "Apple-iPhone7C2": "other",
  "SAMSUNG-SM-B355E Opera": "other",
  "(not set)": "other",
  "Amazon.com": "other",
  "Seznam": "other",
  "NokiaC7-00": "other",
  "lpmqaxwbzyteokrfusnjhvdigc": "other",
  "dohyinzpvbsktjeguxmrqcwafl": "other",
  ";__CT_JOB_ID__:65da7e5f-0f05-4b5d-8d31-1f4d470a2b82;": "other",
  "cajrnbtvqwfkolzyxushpdgime": "other",
  ";__CT_JOB_ID__:0a075729-93a5-43d0-9638-4cbd41d5f5a5;": "other",
  ";__CT_JOB_ID__:97909e28-4228-4b55-8ad5-cc791f2b583c;": "other",
  "starmaker": "other",
  ";__CT_JOB_ID__:6e9dcf2f-f58f-4938-91e3-77e00868177b;": "other",
  ";__CT_JOB_ID__:0b39e7ca-1431-42e3-ba1f-9d8951a65840;": "other",
  "ajsqixbltuvwpmdcokfyzhgren": "other",
  "rbydojcflwzvnuaepmsgxhiktq": "other",
  "hbijxvdyrgnatwzmlcpkfusqoe": "other",
  "uhdypcxbgzajmeqwlofnrsitkv": "other",
  ";__CT_JOB_ID__:89e59554-ad41-4e94-957b-f12bd012530c;": "other",
  "wncrmxukofqljsgvzahiybpdet": "other",
  "mhwxofpevcagujznbsiqlrkytd": "other",
  "ecwozghsufybtdkjrlvxpamiqn": "other",
  "uybjlgntzwpacihremkqsxdovf": "other",
  "wdhtapevfnqzskcroxgjmiybul": "other",
  "afjurnqyolshpibxczdwktmvge": "other",
  "ejpxuidzlmagvthsfbqnkwyocr": "other",
  "ighfsbrmpoctzjqxlywdenvuka": "other",
  "flwadqukonrjegpbisyxztvhcm": "other",
  "Lunascape": "other",
  ";__CT_JOB_ID__:85da5736-a78e-45a9-837e-f5a53e5cd725;": "other",
  ";__CT_JOB_ID__:a80e8e16-6e98-455b-885a-a4dd40f3d344;": "other",
  "kqebrzuwmiycxdvtoljnhsfpga": "other",
  "efkaxnbyohqtspzlvcwrjmigdu": "other",
  "bsfnwveckhgpdoyjxmizruqtla": "other",
  "rpfanjzoxyemsgbtichqkudwlv": "other",
  "Netscape": "other",
  ";__CT_JOB_ID__:76fd1acb-e365-43c0-b967-908bcf5d5b59;": "other",
  "eosutpkiahjzvdgcwxlmyfqbrn": "other",
  "cnwmpegudakrqzljtvfxohbysi": "other",
  "fspmihbxzowgnuctrqykjlvade": "other",
  ";__CT_JOB_ID__:7e575295-571e-4e82-9254-7f2c8bbb9183;": "other",
  "dkagwlhmfqxercuozpnbvtsiyj": "other",
  "ohukwejvqmdtibfrzpycgxanls": "other",
  ";__CT_JOB_ID__:a24a8978-e5e8-4dc9-af66-c4ed89ea25d7;": "other",
  ";__CT_JOB_ID__:fe02e46f-b6ae-41f1-8563-3b40bbb623a9;": "other",
  ";__CT_JOB_ID__:d14534ff-e2fc-4692-92aa-e34508f1c418;": "other",
  ";__CT_JOB_ID__:a4f837b8-8d78-4c42-ba9a-d870cf1a4a7e;": "other",
  ";__CT_JOB_ID__:dd6177aa-1baa-4007-9b38-b7cab4f7611c;": "other",
  ";__CT_JOB_ID__:58e2ecba-7666-4a10-b498-8216457ce472;": "other",
  ";__CT_JOB_ID__:4333777f-bb0c-4a18-935e-df5658dbce2d;": "other",
  ";__CT_JOB_ID__:2547db0b-ec43-452a-a0d4-ff42b7dc7907;": "other",
  ";__CT_JOB_ID__:2e0eca60-83ab-482d-bb81-343d113254fb;": "other",
  ";__CT_JOB_ID__:a7ed0808-e70c-4b19-b1a3-1018bbb7dc7f;": "other",
  "wvsmagudcqeytijorlhxnfzkbp": "other",
  "lhkbrtuwomdeafnqygvxcspizj": "other",
    "Safari (in-app)":"Safari",
}


import json
from collections import defaultdict
# Combine dictionaries and resolve conflicts by selecting the most frequent value
combined_dict = {}
combined_dict = defaultdict(list)

all_mappings = [
    country_mapping1
]
    


for mapping in all_mappings:
    for key, value in mapping.items():
        combined_dict[key].append(value)

# Resolve conflicts
final_dict = {}
for key, values in combined_dict.items():
    final_dict[key] = max(set(values), key=values.count)



# JSON 형태로 파일에 저장
file_name = "./combined_browser_mappings.json"
with open(file_name, 'w', encoding='utf-8') as json_file:
    json.dump(final_dict, json_file, ensure_ascii=False, indent=4)

print(f"{file_name} 파일에 저장되었습니다.")
# Out:
# ./combined_browser_mappings.json 파일에 저장되었습니다.

# %%
OS_mapping1 = {
    "Nokia":"other",
    "SunOS":"other",
    "SymbianOS":"other",
    "FreeBSD":"other",
    "Firefox OS":"other",
    "Nintendo WiiU":"game",
    "Nintendo 3DS":"game",
    "Playstation Vita":"game",
    "Xbox":"game",
    
}

all_mappings = [
    OS_mapping1, 
]

import json
from collections import defaultdict
# Combine dictionaries and resolve conflicts by selecting the most frequent value
combined_dict = {}
combined_dict = defaultdict(list)




for mapping in all_mappings:
    for key, value in mapping.items():
        combined_dict[key].append(value)

# Resolve conflicts
final_dict = {}
for key, values in combined_dict.items():
    final_dict[key] = max(set(values), key=values.count)



# JSON 형태로 파일에 저장
file_name = "./combined_OS_mappings.json"
with open(file_name, 'w', encoding='utf-8') as json_file:
    json.dump(final_dict, json_file, ensure_ascii=False, indent=4)

print(f"{file_name} 파일에 저장되었습니다.")
# Out:
# ./combined_OS_mappings.json 파일에 저장되었습니다.

# %%
traffic_source_mapping1 = {
  "google": "Search Engines",
  "(direct)": "Direct",
  "youtube.com": "Social Media",
  "analytics.google.com": "Google Services",
  "Partners": "Others",
  "sites.google.com": "Google Services",
  "google.com": "Search Engines",
  "bing": "Search Engines",
  "reddit.com": "Social Media",
  "quora.com": "Social Media",
  "qiita.com": "Social Media",
  "baidu": "Search Engines",
  "mail.google.com": "Google Services",
  "m.facebook.com": "Social Media",
  "groups.google.com": "Google Services",
  "dfa": "Others",
  "away.vk.com": "Social Media",
  "facebook.com": "Social Media",
  "support.google.com": "Google Services",
  "yahoo": "Search Engines",
  "plus.url.google.com": "Google Services",
  "blog.golang.org": "Blogs",
  "l.facebook.com": "Social Media",
  "dealspotr.com": "Others",
  "lunametrics.com": "Others",
  "productforums.google.com": "Google Services",
  "duckduckgo.com": "Search Engines",
  "t.co": "Social Media",
  "google.co.jp": "Search Engines",
  "linkedin.com": "Social Media",
  "plus.google.com": "Google Services",
  "googleads.g.doubleclick.net": "Google Services",
  "optimize.google.com": "Google Services",
  "sashihara.jp": "Others",
  "adwords.google.com": "Google Services",
  "lm.facebook.com": "Social Media",
  "int.search.tb.ask.com": "Search Engines",
  "ask": "Search Engines",
  "aulagrado.esic.edu": "Educational",
  "pinterest.com": "Social Media",
  "online-metrics.com": "Others",
  "outlook.live.com": "Email Services",
  "phandroid.com": "Tech News",
  "docs.google.com": "Google Services",
  "myactivity.google.com": "Google Services",
  "google.co.in": "Search Engines",
  "l.messenger.com": "Social Media",
  "google.co.uk": "Search Engines",
  "keep.google.com": "Google Services",
  "in.search.yahoo.com": "Search Engines",
  "m.baidu.com": "Search Engines",
  "learn.pct.edu": "Educational",
  "ca.search.yahoo.com": "Search Engines",
  "google.ru": "Search Engines",
  "canopy.uc.edu": "Educational",
  "msn.com": "Portals",
  "google.com.eg": "Search Engines",
  "youtube.thinkwithgoogle.com": "Google Services",
  "github.com": "Tech Platforms",
  "google.com.br": "Search Engines",
  "myasucourses.asu.edu": "Educational",
  "vk.com": "Social Media",
  "r.search.aol.com": "Search Engines",
  "google.de": "Search Engines",
  "m.youtube.com": "Social Media",
  "us.search.yahoo.com": "Search Engines",
  "tw.search.yahoo.com": "Search Engines",
  "uk.search.yahoo.com": "Search Engines",
  "search.xfinity.com": "Others",
  "arstechnica.com": "Tech News",
  "google.com.au": "Search Engines",
  "images.google.com": "Google Services",
  "gophergala.com": "Others",
  "google.co.za": "Search Engines",
  "s0.2mdn.net": "Others",
  "google.nl": "Search Engines",
  "bluequill.franklin.edu": "Educational",
  "google.co.th": "Search Engines",
  "google.it": "Search Engines",
  "google.com.tr": "Search Engines",
  "espanol.search.yahoo.com": "Search Engines",
  "amp.reddit.com": "Social Media",
  "evernote.com": "Others",
  "google.com.ua": "Search Engines",
  "search.1and1.com": "Search Engines",
  "hangouts.google.com": "Google Services",
  "connect.googleforwork.com": "Google Services",
  "es.search.yahoo.com": "Search Engines",
  "google.co.id": "Search Engines",
  "web.whatsapp.com": "Social Media",
  "google.com.ng": "Search Engines",
  "mx.search.yahoo.com": "Search Engines",
  "search.tb.ask.com": "Search Engines",
  "go.mail.ru": "Search Engines",
  "mail.yahoo.com": "Email Services",
  "cn.bing.com": "Search Engines",
  "se.search.yahoo.com": "Search Engines",
  "businessinsider.com": "Others",
  "google.com.mx": "Search Engines",
  "online.fullsail.edu": "Educational",
  "wikihow.com": "Others",
  "nl.search.yahoo.com": "Search Engines",
  "learn.colorado.edu": "Educational",
  "fr.search.yahoo.com": "Search Engines",
  "au.search.yahoo.com": "Search Engines",
  "it.pinterest.com": "Social Media",
  "chatwork.com": "Others",
  "startpage.com": "Search Engines",
  "google.es": "Search Engines",
  "twitter.com": "Social Media",
  "fi.search.yahoo.com": "Search Engines",
  "web.facebook.com": "Social Media",
  "getpocket.com": "Others",
  "google.com.sa": "Search Engines",
  "it.search.yahoo.com": "Search Engines",
  "sg.search.yahoo.com": "Search Engines",
  "fr-fr.facebook.com": "Social Media",
  "cse.google.com": "Google Services",
  "calendar.google.com": "Google Services",
  "search.mysearch.com": "Search Engines",
  "blackboard.bentley.edu": "Educational",
  "suche.t-online.de": "Search Engines",
  "kik.com": "Social Media",
  "business.facebook.com": "Social Media",
  "seroundtable.com": "Tech News",
  "basecamp.com": "Others",
  "news.ycombinator.com": "Tech News",
  "google.com.pk": "Search Engines",
  "marketingland.com": "Others",
  "ca-mg5.mail.yahoo.com": "Email Services",
  "p.qiao.baidu.com": "Others",
  "google.ca": "Search Engines",
  "yandex": "Search Engines",
  "results.searchlock.com": "Search Engines",
  "es.yhs4.search.yahoo.com": "Search Engines",
  "cl.search.yahoo.com": "Search Engines",
  "goto.google.com": "Google Services",
  "m.wikihow.com": "Others",
  "google.com.tw": "Search Engines",
  "blognone.com": "Tech News",
  "google.com.hk": "Search Engines",
  "google.co.kr": "Search Engines",
  "google.co.nz": "Search Engines",
  "mail.aol.com": "Email Services",
  "search.snapdo.com": "Search Engines",
  "mail1.swic.edu": "Educational",
  "google.be": "Search Engines",
  "google.com.bd": "Search Engines",
  "kidrex.org": "Others",
  "so.com": "Search Engines",
  "google.fr": "Search Engines",
  "feedly.com": "Others",
  "ch.search.yahoo.com": "Search Engines",
  "google.lv": "Search Engines",
  "malaysia.search.yahoo.com": "Search Engines",
  "web.telegram.org": "Social Media",
  "ph.search.yahoo.com": "Search Engines",
  "google.by": "Search Engines",
  "my.yahoo.com": "Portals",
  "lisham-web.blogspot.com": "Blogs",
  "nl.pinterest.com": "Social Media",
  "de.wow.com": "Others",
  "google.iq": "Search Engines",
  "google.co.il": "Search Engines",
  "google.pl": "Search Engines",
  "images.google.com.br": "Google Services",
  "google.pt": "Search Engines",
  "cz.pinterest.com": "Social Media",
  "google.jo": "Search Engines",
  "google.ie": "Search Engines",
  "qc.search.yahoo.com": "Search Engines",
  "earth.google.com": "Google Services",
  "br.search.yahoo.com": "Search Engines",
  "search.earthlink.net": "Search Engines",
  "google.com.ec": "Search Engines",
  "ru.pinterest.com": "Social Media",
  "hk.search.yahoo.com": "Search Engines",
}


all_mappings = [
    traffic_source_mapping1, 
]


import json
from collections import defaultdict
# Combine dictionaries and resolve conflicts by selecting the most frequent value
combined_dict = {}
combined_dict = defaultdict(list)




for mapping in all_mappings:
    for key, value in mapping.items():
        combined_dict[key].append(value) # 이거 소문자로 저장

# Resolve conflicts
final_dict = {}
for key, values in combined_dict.items():
    final_dict[key] = max(set(values), key=values.count)



# JSON 형태로 파일에 저장
file_name = "./combined_traffic_source_mappings.json"
with open(file_name, 'w', encoding='utf-8') as json_file:
    json.dump(final_dict, json_file, ensure_ascii=False, indent=4)

print(f"{file_name} 파일에 저장되었습니다.")
# Out:
# ./combined_traffic_source_mappings.json 파일에 저장되었습니다.
